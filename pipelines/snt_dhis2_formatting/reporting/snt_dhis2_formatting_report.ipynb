# %%
# 💡 Comments / Questions & To Do's:
# - filter by YEAR keep only 2022-2024): 
#     1. Why these years? Arbitrary choice? Based on what? linked to what?
#     2. Is this a paramater is some other pipeline? if so, should be integrated here somehow 
# - Missing data: why do we have NA values for population? Are these real NA (missing data) or 0?
# - OUTLIERS: there are clear outliers (i.e., DS AGADEZ): shall we do some simple data cleaning here?
# - Population catagories (breaks) do we have a specific scale in mind 
#   (i.e., use same as another country) or can I set it based on the data

# %%
# TO DO / FINISH:
# - add safety "if" logic so nb does not fail if data is missing or wrong path ...
#   - (maybe) also add meaningful messages
# - Add code to export PNG files of relevant figures
# - Set dynamic boundaries for POPULATION categories? (so can use same code in different countries)
# - Clean code to avoid redundancies (especially ggplot stuff, a lot of copy pasted ...)

# %% [markdown]
# ## 0. Paths and Config

# %%
# Set SNT Paths
SNT_ROOT_PATH  <- "~/workspace"
CODE_PATH      <- file.path(SNT_ROOT_PATH, "code")
CONFIG_PATH    <- file.path(SNT_ROOT_PATH, "configuration")
PIPELINE_PATH  <- file.path(SNT_ROOT_PATH, "pipelines", "snt_dhis2_formatting")

REPORTING_NB_PATH <- file.path(SNT_ROOT_PATH, "pipelines/snt_dhis2_formatting/reporting")

# Create output directories if they don't exist (before loading utils)
figures_dir <- file.path(REPORTING_NB_PATH, "outputs", "figures")
if (!dir.exists(figures_dir)) {
  dir.create(figures_dir, recursive = TRUE)
  print(paste0("Created figures directory: ", figures_dir))
}

# %%
# Load util functions
source(file.path(CODE_PATH, "snt_utils.r"))
source(file.path(PIPELINE_PATH, "utils", "snt_dhis2_formatting_report.r"))

# %%
required_packages <- c(
    "tidyverse", 
    "arrow", 
    "sf", 
    "reticulate",
    "patchwork"
) 

# Execute function
install_and_load(required_packages)

# %%
# Set environment to load openhexa.sdk from the right environment
Sys.setenv(PROJ_LIB = "/opt/conda/share/proj")
Sys.setenv(GDAL_DATA = "/opt/conda/share/gdal")
Sys.setenv(RETICULATE_PYTHON = "/opt/conda/bin/python")

# Load openhexa.sdk
reticulate::py_config()$python
openhexa <- import("openhexa.sdk")

# %%
# Load SNT config
config_json <- tryCatch({ jsonlite::fromJSON(file.path(CONFIG_PATH, "SNT_config.json"))},
    error = function(e) {
        msg <- paste0("Error while loading configuration", conditionMessage(e))  
        cat(msg)   
        stop(msg) 
    })

# %%
# Configuration variables
dataset_name <- config_json$SNT_DATASET_IDENTIFIERS$DHIS2_DATASET_FORMATTED
COUNTRY_CODE <- config_json$SNT_CONFIG$COUNTRY_CODE
COUNTRY_NAME <- config_json$SNT_CONFIG$COUNTRY_NAME
ADM_2 <- toupper(config_json$SNT_CONFIG$DHIS2_ADMINISTRATION_2)

# Get indicator variables to subset programmatically the dataset (instead of hardcoding col names)
indicator_vars <- config_json$DHIS2_DATA_DEFINITIONS$DHIS2_INDICATOR_DEFINITIONS |> names()

# %% [markdown]
# ## 1. Import data

# %% [markdown]
# ### Routine data (raw from DHIS2 Extract)

# %%
# import analytics DHIS2 data
routine_data <- tryCatch({ get_latest_dataset_file_in_memory(dataset_name, paste0(COUNTRY_CODE, "_routine.parquet")) }, 
                  error = function(e) {
                      msg <- paste0("[WARNING] Error while loading DHIS2 Routine data for: " , COUNTRY_CODE, 
                                    " the report cannot be executed. [ERROR DETAILS] ", conditionMessage(e))
                      stop(msg)
                      })

printdim(routine_data)

# %% [markdown]
# ## ⚠️ TEMP safety measure (this should be fixed in the main code!) - remove duplicated rows!
# There are duplicated rows in routine data ... !

# %%
# GP:why does it look like routine_data has a lot of repeated cols ...?
dim(routine_data)[1]/dim(distinct(routine_data))[1]

# Make this a printed message if the ratio is above is > 1 
if (dim(routine_data)[1]/dim(distinct(routine_data))[1] > 1) {
  print(paste0("Warning: The dataset contains duplicated rows. The ratio of total rows to distinct rows is: ", 
               round(dim(routine_data)[1]/dim(distinct(routine_data))[1], 2)))

   # Run distinct only if there are duplicated rows 
    routine_data <- distinct(routine_data)
    print(paste0("After removing duplicates, the dataset now has ", dim(routine_data)[1], " rows and ", dim(routine_data)[2], " columns."))
}

# %%
head(routine_data)

# %% [markdown]
# ### Population data

# %%
population_data <- tryCatch({ get_latest_dataset_file_in_memory(dataset_name, paste0(COUNTRY_CODE, "_population.parquet")) }, 
                  error = function(e) {
                      msg <- paste0(COUNTRY_NAME , " Population data is not available in dataset : " , dataset_name, " last version.")
                      log_msg(msg, "warning")
                      population_data <- NULL
                      })

printdim(population_data)

# %% [markdown]
# ### Shapes

# %%
shapes_data <- tryCatch({ get_latest_dataset_file_in_memory(dataset_name, paste0(COUNTRY_CODE, "_shapes.geojson")) }, 
                  error = function(e) {                      
                      msg <- paste0(COUNTRY_NAME , " Shapes data is not available in dataset : " , dataset_name, " last version.")
                      log_msg(msg, "warning")
                      shapes_data <- NULL
                      })

printdim(shapes_data)

# %%
# Simplify shapes to make it easier to render (fewer points per polygon)
# Set dTolerance bigger to keep fewer points
shapes_data_stsimplified <- st_simplify(shapes_data, dTolerance = 10000) 

print(paste0("Original shapes data points: ", sum(mapply(function(g) length(unlist(g)), sf::st_geometry(shapes_data))))) 
print(paste0("Simplified shapes data points: ", sum(mapply(function(g) length(unlist(g)), sf::st_geometry(shapes_data_stsimplified)))))

# %% [markdown]
# # **Complétude des indicateurs composites**

# %% [markdown]
# # 1. Complétude du rapportage des indicateurs composites / Reporting Completeness of Composite Indicators

# %% [markdown]
# ## 1.1 Proportion de formations sanitaires ayant rapporté des valeurs nulles, manquantes (NULL) ou positives pour chaque indicateur

# %%
# Step 0: Rename your data for convenience
data <- routine_data
# GP: find better name ... !

# Step 1: Convert PERIOD to DATE
data <- data %>%
  mutate(
    DATE = ymd(paste0(PERIOD, "01"))
  )

# %% [markdown]
# ### 💡: extracting the names of indicators from the config.json file should be a function since we use it in multiple places!

# %%
# Step 2: Reshape wide to long: INDICATOR = column name (e.g., CONF), VALUE = value
# indicator_vars <- setdiff(names(data), c(
#   "PERIOD", "YEAR", "MONTH", "OU_ID", "OU_NAME", "ADM1_NAME", "ADM1_ID", "ADM2_NAME", "ADM2_ID", "DATE"
# ))
# GP: indicators can be extracted from config file instead ...
indicator_vars <- config_json$DHIS2_DATA_DEFINITIONS$DHIS2_INDICATOR_DEFINITIONS |> names()

indicator_vars

# %%
long_data <- data %>%
  pivot_longer(cols = any_of(indicator_vars),
               names_to = "INDICATOR",
               values_to = "VALUE") %>%
  rename(OU = OU_ID) # GP: I'd keep OU_ID ... !

head(long_data)

# %%
# Step 3: Build expected full grid (OU × INDICATOR × DATE)
full_grid <- expand_grid(
  OU = unique(long_data$OU),
  INDICATOR = unique(long_data$INDICATOR),
  DATE = unique(long_data$DATE)
)

# %%
head(full_grid)

# %%
# Step 4: Join and assess reporting status
reporting_check <- full_grid %>%
  left_join(
    long_data %>% select(OU, INDICATOR, DATE, VALUE),
    by = c("OU", "INDICATOR", "DATE")
  ) %>%
  distinct() |> # GP added
  mutate(
    is_missing = is.na(VALUE),
    is_zero = VALUE == 0 & !is.na(VALUE),
    is_positive = VALUE > 0 & !is.na(VALUE)
  )

# %%
head(reporting_check)

# %%
# Step 5: Summarise reporting status
reporting_summary <- reporting_check %>%
  group_by(INDICATOR, DATE) %>% 
  summarise(
    n_total = n_distinct(OU),
    n_missing = sum(is_missing),
    n_zero = sum(is_zero),
    n_positive = sum(is_positive),
    pct_missing = ifelse(n_total > 0, 100 * n_missing / n_total, 0),
    pct_zero = ifelse(n_total > 0, 100 * n_zero / n_total, 0),
    pct_positive = ifelse(n_total > 0, 100 * n_positive / n_total, 0),
    .groups = "drop"
  )

head(reporting_summary)

# %%
# Check to see if n_total is = to the some of n_missing, n_zero and n_positive for each INDICATOR-DATE combo
reporting_summary %>%
  mutate(n_sum = (n_missing + n_zero + n_positive)) |>
  # head() |>
  filter(n_sum > n_total)

  # FIXED NOW :D (tibble is empty)

# %%
# Step 6: Prepare plot-ready data
plot_data <- reporting_summary %>%
  pivot_longer(
    cols = starts_with("pct_"),
    names_to = "Status",
    values_to = "Percentage"
  ) %>%
  mutate(
    Status = recode(Status,
                    pct_missing = "Valeur manquante",
                    pct_zero = "Valeur zéro rapportée", # GP:changed "nulle" to "zéro" 
                    pct_positive = "Valeur positive rapportée")
  ) %>%
  complete(INDICATOR, DATE, Status, fill = list(Percentage = 0))

# %%
# ⚠️ GP: I broke down this big cell into the individual steps above, to make it easier to read and debug if needed.
# ⚠️ and also BECAUSE IT WAS TAKING FOREVER TO RUN ... ! (>4 minutes ... !)

# # Step 0: Rename your data for convenience
# data <- routine_data
# # GP: find better name ... !

# # Step 1: Convert PERIOD to DATE
# data <- data %>%
#   mutate(
#     DATE = ymd(paste0(PERIOD, "01"))
#   )

# # # Step 2: Reshape wide to long: INDICATOR = column name (e.g., CONF), VALUE = value
# # indicator_vars <- setdiff(names(data), c(
# #   "PERIOD", "YEAR", "MONTH", "OU_ID", "OU_NAME", "ADM1_NAME", "ADM1_ID", "ADM2_NAME", "ADM2_ID", "DATE"
# # ))
# # # GP: indicators extracted from config file updtream instead ...

# long_data <- data %>%
#   pivot_longer(cols = any_of(indicator_vars),
#                names_to = "INDICATOR",
#                values_to = "VALUE") %>%
#   rename(OU = OU_ID) # GP: I'd keep OU_ID ... !

# # Step 3: Build expected full grid (OU × INDICATOR × DATE)
# full_grid <- expand_grid(
#   OU = unique(long_data$OU),
#   INDICATOR = unique(long_data$INDICATOR),
#   DATE = unique(long_data$DATE)
# )

# # Step 4: Join and assess reporting status
# reporting_check <- full_grid %>%
#   left_join(
#     long_data %>% select(OU, INDICATOR, DATE, VALUE),
#     by = c("OU", "INDICATOR", "DATE")
#   ) %>%
#   mutate(
#     is_missing = is.na(VALUE),
#     is_zero = VALUE == 0 & !is.na(VALUE),
#     is_positive = VALUE > 0 & !is.na(VALUE)
#   )

# # Step 5: Summarise reporting status
# reporting_summary <- reporting_check %>%
#   # group_by(INDICATOR, DATE) %>% # GP
#   # GP to see if this fixes the issue with percentages being 100% when n_total is 0 (i.e., no OUs reporting for that indicator-date combo) ...
#   group_by(OU, INDICATOR, DATE) |>
#   summarise(
#     n_total = n_distinct(OU),
#     n_missing = sum(is_missing),
#     n_zero = sum(is_zero),
#     n_positive = sum(is_positive),
#     pct_missing = ifelse(n_total > 0, 100 * n_missing / n_total, 0),
#     pct_zero = ifelse(n_total > 0, 100 * n_zero / n_total, 0),
#     pct_positive = ifelse(n_total > 0, 100 * n_positive / n_total, 0),
#     .groups = "drop"
#   )

# # Step 6: Prepare plot-ready data
# plot_data <- reporting_summary %>%
#   pivot_longer(
#     cols = starts_with("pct_"),
#     names_to = "Status",
#     values_to = "Percentage"
#   ) %>%
#   mutate(
#     Status = recode(Status,
#                     pct_missing = "Valeur manquante",
#                     pct_zero = "Valeur nulle rapportée",
#                     pct_positive = "Valeur positive rapportée")
#   ) %>%
#   complete(INDICATOR, DATE, Status, fill = list(Percentage = 0))

# %%
options(repr.plot.width = 17, repr.plot.height = 10)
ggplot(plot_data, aes(x = DATE, y = Percentage, fill = Status)) +
  geom_col(position = "stack") +
  facet_wrap(~ INDICATOR, scales = "free_y", ncol = 4) +
  scale_y_continuous() +
  scale_fill_manual(values = c(
    "Valeur manquante" = "tomato",
    "Valeur zéro rapportée" = "skyblue",
    "Valeur positive rapportée" = "green"
  )) +
  labs(
    title = "Taux de rapportage par indicateur (niveau formation sanitaire)",
    subtitle = "Proportion des valeurs rapportées par mois et par indicateur",
    x = "Mois", y = "% des formations sanitaires",
    fill = "Statut du rapportage"
  ) +
  theme_minimal(base_size = 16) +
  theme(
    plot.title = element_text(face = "bold", size = 20),
    strip.text = element_text(size = 16),
    axis.title = element_text(size = 16),
    axis.text = element_text(size = 16)
  )

# %% [markdown]
# ## 1.2 Proportion des districts ayant rapporté des valeurs nulles, manquantes (NULL) ou positives pour chaque indicateur.

# %%
# # Step 0: Rename for convenience
# data <- routine_data

# # Step 1: Convert PERIOD to proper Date
# data <- data %>%
#   mutate(Date = ymd(paste0(PERIOD, "01"))) # DATE

# # Step 2: Identify indicator columns
# indicator_cols <- setdiff(names(data), c(
#   "PERIOD", "YEAR", "MONTH", "OU_ID", "OU_NAME",
#   "ADM1_NAME", "ADM1_ID", "ADM2_NAME", "ADM2_ID", "Date"
# ))

# %%
# Step 3: Reshape to long format
data_long <- data %>%
  select(ADM2_ID, OU_ID, DATE, any_of(indicator_vars)) %>% # Date
  pivot_longer(cols = any_of(indicator_vars),
               names_to = "Indicator", values_to = "value") %>%
  mutate(value = as.numeric(value))

# %%
# Step 4: Full expected grid at ADM2 level
full_grid <- expand_grid(
  ADM2_ID = unique(data_long$ADM2_ID),
  Indicator = unique(data_long$Indicator),
  DATE = unique(data_long$DATE)  # GP:was "Date"
)

# %%
# Step 5: Detect if *any* health facility reported per district × indicator × date
reporting_check <- data_long %>%
  group_by(ADM2_ID, Indicator, DATE) %>% # GP:was "Date"
  summarise(
    is_missing = all(is.na(value)),
    is_zero = all(value == 0, na.rm = TRUE),
    is_positive = any(value > 0, na.rm = TRUE),
    .groups = "drop"
  )

# %%
# Step 6: Join with full grid to fill in missing ADM2s
reporting_full <- full_grid %>%
  left_join(reporting_check, by = c("ADM2_ID", "Indicator", "DATE")) %>% # GP:was "Date"
  mutate(
    is_missing = replace_na(is_missing, TRUE),
    is_zero = replace_na(is_zero, FALSE),
    is_positive = replace_na(is_positive, FALSE)
  )

head(reporting_full)

# %%
# Step 7: Summarise by Indicator and Date
reporting_summary <- reporting_full %>%
  group_by(Indicator, DATE) %>%
  summarise(
    n_total = n_distinct(ADM2_ID),
    n_missing = sum(is_missing),
    n_zero = sum(is_zero & !is_missing),
    n_positive = sum(is_positive),
    pct_missing = ifelse(n_total > 0, 100 * n_missing / n_total, 0),
    pct_zero = ifelse(n_total > 0, 100 * n_zero / n_total, 0),
    pct_positive = ifelse(n_total > 0, 100 * n_positive / n_total, 0),
    .groups = "drop"
  )

head(reporting_summary)

# %%
# Step 8: Reshape for plotting
plot_data <- reporting_summary %>%
  pivot_longer(cols = starts_with("pct_"),
               names_to = "Status", values_to = "Percentage") %>%
  mutate(Status = recode(Status,
                         pct_missing = "Valeur manquante",
                         pct_zero = "Valeur zéro rapportée", # GP: changed "zéro" to "nulle" 
                         pct_positive = "Valeur positive rapportée")) %>%
  complete(Indicator, DATE, Status, fill = list(Percentage = 0))

head(plot_data)
# GP: werid that we still have the n_* cols (and they are very confusing ... !)

# %%
# Step 9: Plot
ggplot(plot_data, aes(x = DATE, y = Percentage, fill = Status)) +
  geom_col(position = "stack") +
  facet_wrap(~ Indicator, scales = "free_y") +
  scale_y_continuous(limits = c(0, 100)) +
  scale_fill_manual(values = c(
    "Valeur manquante" = "tomato",
    "Valeur zéro rapportée" = "skyblue",
    "Valeur positive rapportée" = "green"
  )) +
  labs(
    title = "Taux de rapportage par indicateur (niveau district)",
    subtitle = "Proportion des districts (ADM2_ID) rapportant chaque mois",
    x = "Mois", y = "% des districts",
    fill = "Statut du rapportage"
  ) +
  theme_minimal(base_size = 14) +
  theme(
    plot.title = element_text(face = "bold", size = 18),
    strip.text = element_text(size = 14),
    axis.title = element_text(size = 14),
    axis.text = element_text(size = 12)
  )

# %%
# ⚠️ GP: I broke down this big cell into the individual steps above, to make it easier to read and debug if needed.
# ⚠️ GP: and also BECAUSE IT WAS TAKING FOREVER TO RUN ... ! (>4 minutes ... !)

# # GP: these steps are repeated from before ...
# # # Step 0: Rename for convenience
# # data <- routine_data

# # # Step 1: Convert PERIOD to proper Date
# # data <- data %>%
# #   mutate(Date = ymd(paste0(PERIOD, "01"))) # GP:was DATE in previous section ...

# # # Step 2: Identify indicator columns
# # indicator_cols <- setdiff(names(data), c(
# #   "PERIOD", "YEAR", "MONTH", "OU_ID", "OU_NAME",
# #   "ADM1_NAME", "ADM1_ID", "ADM2_NAME", "ADM2_ID", "Date"
# # ))

# # Step 3: Reshape to long format
# data_long <- data %>%
#   select(ADM2_ID, OU_ID, DATE, any_of(indicator_cols)) %>%
#   pivot_longer(cols = any_of(indicator_cols),
#                names_to = "Indicator", values_to = "value") %>%
#   mutate(value = as.numeric(value))

# # Step 4: Full expected grid at ADM2 level
# full_grid <- expand_grid(
#   ADM2_ID = unique(data_long$ADM2_ID),
#   Indicator = unique(data_long$Indicator),
#   DATE = unique(data_long$DATE)
# )

# # Step 5: Detect if *any* health facility reported per district × indicator × date
# reporting_check <- data_long %>%
#   group_by(ADM2_ID, Indicator, DATE) %>%
#   summarise(
#     is_missing = all(is.na(value)),
#     is_zero = all(value == 0, na.rm = TRUE),
#     is_positive = any(value > 0, na.rm = TRUE),
#     .groups = "drop"
#   )

# # Step 6: Join with full grid to fill in missing ADM2s
# reporting_full <- full_grid %>%
#   left_join(reporting_check, by = c("ADM2_ID", "Indicator", "DATE")) %>%
#   mutate(
#     is_missing = replace_na(is_missing, TRUE),
#     is_zero = replace_na(is_zero, FALSE),
#     is_positive = replace_na(is_positive, FALSE)
#   )

# # Step 7: Summarise by Indicator and Date
# reporting_summary <- reporting_full %>%
#   group_by(Indicator, DATE) %>%
#   summarise(
#     n_total = n_distinct(ADM2_ID),
#     n_missing = sum(is_missing),
#     n_zero = sum(is_zero & !is_missing),
#     n_positive = sum(is_positive),
#     pct_missing = ifelse(n_total > 0, 100 * n_missing / n_total, 0),
#     pct_zero = ifelse(n_total > 0, 100 * n_zero / n_total, 0),
#     pct_positive = ifelse(n_total > 0, 100 * n_positive / n_total, 0),
#     .groups = "drop"
#   )

# # Step 8: Reshape for plotting
# plot_data <- reporting_summary %>%
#   pivot_longer(cols = starts_with("pct_"),
#                names_to = "Status", values_to = "Percentage") %>%
#   mutate(Status = recode(Status,
#                          pct_missing = "Valeur manquante",
#                          pct_zero = "Valeur nulle rapportée",
#                          pct_positive = "Valeur positive rapportée")) %>%
#   complete(Indicator, DATE, Status, fill = list(Percentage = 0))

# # Step 9: Plot
# ggplot(plot_data, aes(x = DATE, y = Percentage, fill = Status)) +
#   geom_col(position = "stack") +
#   facet_wrap(~ Indicator, scales = "free_y") +
#   scale_y_continuous(limits = c(0, 100)) +
#   scale_fill_manual(values = c(
#     "Valeur manquante" = "tomato",
#     "Valeur nulle rapportée" = "skyblue",
#     "Valeur positive rapportée" = "green"
#   )) +
#   labs(
#     title = "Taux de rapportage par indicateur (niveau district)",
#     subtitle = "Proportion des districts (ADM2_ID) rapportant chaque mois",
#     x = "Mois", y = "% des districts",
#     fill = "Statut du rapportage"
#   ) +
#   theme_minimal(base_size = 14) +
#   theme(
#     plot.title = element_text(face = "bold", size = 18),
#     strip.text = element_text(size = 14),
#     axis.title = element_text(size = 14),
#     axis.text = element_text(size = 12)
#   )

# %% [markdown]
# # 2. Cohérence interne des indicateurs composites

# %% [markdown]
# ## 2.2 Cohérence des indicateurs

# %%
# # GP: this does not make sense ... 

# routine_data <- routine_data %>%
#   mutate(across(where(is.list), ~ map_dbl(., ~ sum(as.numeric(.x), na.rm = TRUE))))

# # Now head() should work
# head(routine_data, 3)

# %%
# Step 1: Extract year and month from PERIOD
# routine_hd_month <- routine_data_clean %>% # GP: this was from MAD15 -> MAD10 removal of outliers (step deleted now)
routine_hd_month <- routine_data %>% # GP
  mutate(
    YEAR = substr(PERIOD, 1, 4),
    MONTH = substr(PERIOD, 5, 6)
  ) %>%
  group_by(ADM2_ID, YEAR, MONTH) %>%
  # GP: Make summarise only on indicator columns, which are defined in indicator_vars
  summarise(across(all_of(indicator_vars), ~ sum(.x, na.rm = TRUE)),
    .groups = "drop"
  )

# %%
head(routine_hd_month, 3)

# %%
# Just FYI: how many data points do we have for the SUSP vs TEST plot?
n_points <- nrow(routine_hd_month)
# n_points

# Print info message about number of data points if we plot all data in a scatterplot
if (n_points > 1000) {
  print(paste0("Warning: The dataset contains ", n_points, " data points. This may take a long time to render. Consider filtering the data or using a sample for plotting."))
}

# %%
# Now, we want to make 3 coherence plots: 
# 1. SUSP vs TEST (always data for this, as these are the "essential" indicators)
# 2. SUSP vs CONF (always data for this, as these are the "essential" indicators)
# 3. SUSP vs MALTREAT (might not have data for this, as MALTREAT is not an "essential" indicator)

# To make plots better and avoid insane rendering ...
# 1) Cut out "outliers" by simply removing points above the _n_th percentile of SUSP (or TEST, CONF, MALTREAT depending on the plot)
# 2) Subsample plot by randomly sampling 1000 points if we have more than 1000 points after removing outliers (GP: this is arbitrary, we can discuss about it)
#    Because rendering >1000 points inside a notebook makes it insanely slow and heavy ... !

# GP: I suggest to do this in a function, so we can easily apply it to the 3 plots we want to make ... !
# Write the function to make the coherence plots with outlier removal and subsampling
make_coherence_plot <- function(data, percentile_cutoff, x_var, y_var) {
  # Step 1: Remove outliers above the nth percentile of x_var
  x_threshold <- quantile(data[[x_var]], percentile_cutoff, na.rm = TRUE)
  data_filtered <- data %>%
    filter(.data[[x_var]] <= x_threshold) 
  # Remove outliers above the nth percentile of y_var as well (to be more robust)
  y_threshold <- quantile(data[[y_var]], percentile_cutoff, na.rm = TRUE)
  data_filtered <- data_filtered %>%
    filter(.data[[y_var]] <= y_threshold)

    # Step 2: Subsample if we have more than 1000 points
    if (nrow(data_filtered) > 1000) {
      set.seed(123) # for reproducibility
      data_filtered <- data_filtered %>%
        sample_n(1000)
    }   
# define title based on x_var and y_var and include number of points after filtering and subsampling and values of the thresholds used for outlier removal
    title <- glue::glue("Coherence plot: {y_var} vs {x_var}\n")
    subtitle <- glue::glue(
                    "Data points after filtering: {nrow(data_filtered)} ({round(100 * nrow(data_filtered) / nrow(data), 2)}% of original data)\n",
                    "Outlier removal thresholds based on {percentile_cutoff}th percentile."
                    )

    # Step 3: Make the scatter plot with black dashed abline (y=x), points colored in "red" if y_var > x_var and "#1e81b0" otherwise
    print("This plot partially reflects what suggested by AHADI (https://ahadi-analytics.github.io/snt-code-library/english/library/data/routine_cases/quality_control.html), 
    but it does not yet fully incorporate all their suggestions. (Work in progress ... !)")
    ggplot(data_filtered, aes(x = .data[[x_var]], y = .data[[y_var]])) +
      geom_point(alpha = 0.5, aes(color = .data[[y_var]] > .data[[x_var]])) +
      scale_color_manual(values = c("TRUE" = "red", "FALSE" = "#1e81b0")) +
      geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "black") +
      labs(title = title, subtitle = subtitle, x = x_var, y = y_var) +
      theme_minimal() +
      coord_equal() +
      ggplot2::theme(
        plot.title = ggplot2::element_text(size = 16, face = "bold"),
        plot.subtitle = ggplot2::element_text(size = 14),
        axis.title = ggplot2::element_text(size = 14),
        legend.text = ggplot2::element_text(size = 12),
        legend.position = "right",
        axis.text = ggplot2::element_text(angle = 90,
                                        vjust = 0.5,
                                        hjust = 1)
  ) 
}

# %%
# # Test the function with SUSP vs TEST plot
# plot_susp_test <- make_coherence_plot(
#   data = routine_hd_month,
#   percentile_cutoff = 0.95,
#   x_var = "SUSP",
#   y_var = "TEST"
#   )

# plot_susp_test

# %%
# # Step 1: Extract year and month from PERIOD
# # routine_hd_month <- routine_data_clean %>%
# routine_hd_month <- routine_data %>% # GP
#   mutate(
#     YEAR = substr(PERIOD, 1, 4),
#     MONTH = substr(PERIOD, 5, 6)
#   ) %>%
#   group_by(ADM2_ID, YEAR, MONTH) %>%
#   summarise(
#     SUSP = sum(SUSP, na.rm = TRUE),
#     TEST = sum(TEST, na.rm = TRUE),
#     CONF = sum(CONF, na.rm = TRUE),
#     MALTREAT = sum(MALTREAT, na.rm = TRUE),
#     PRES = sum(PRES, na.rm = TRUE),
#     .groups = "drop"
#   )

# # Step 2: Create scatter plots
# options(repr.plot.width = 14, repr.plot.height = 6)

# GP: define global percentile cutoff for outlier removal (can be changed if needed, e.g., to 0.90 or 0.99 depending on how much we want to filter out)
percentile_cutoff <- 0.995

# p1 <- ggplot(routine_hd_month, aes(x = SUSP, y = TEST)) +
#   geom_point(alpha = 0.5, color = "blue") +
#   geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "red") +
#   labs(title = "Suspectés vs Testés", x = "Cas suspectés", y = "Cas testés") +
#   theme_minimal(base_size = 16) +
#   # make y and x axis have a 1 to 1 scale
#   coord_fixed() +
#   theme(aspect.ratio = 1)
  # GP
p1 <- make_coherence_plot(
  data = routine_hd_month,
  percentile_cutoff = percentile_cutoff,
  x_var = "SUSP",
  y_var = "TEST"
)

# p2 <- ggplot(routine_hd_month, aes(x = TEST, y = CONF)) +
#   geom_point(alpha = 0.5, color = "darkgreen") +
#   geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "red") +
#   labs(title = "Testés vs Confirmés", x = "Cas testés", y = "Cas confirmés") +
#   theme_minimal(base_size = 16)
p2 <- make_coherence_plot(
  data = routine_hd_month,
  percentile_cutoff = percentile_cutoff,
  x_var = "TEST",
  y_var = "CONF"
)

# p3 <- ggplot(routine_hd_month, aes(x = CONF, y = MALTREAT)) +
#   geom_point(alpha = 0.5, color = "purple") +
#   geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "red") +
#   labs(title = "Confirmés vs Traités", x = "Cas confirmés", y = "Cas traités") +
#   theme_minimal(base_size = 16)
p3 <- make_coherence_plot(
  data = routine_hd_month,
  percentile_cutoff = percentile_cutoff,
  x_var = "CONF",
  y_var = "MALTREAT"
)

# # Step 3: Combine plots
# (p1 | p2 | p3) #+ plot_layout(guides = "collect") 
p1
p2
p3

# %%
# Export p1 as PNG 
ggsave(filename = file.path(figures_dir, paste0(COUNTRY_CODE, "_coherence_SUSP_TEST.png")), plot = p1, width = 21, height = 21, units = "cm", dpi = 300)
# Export p2 as PNG
ggsave(filename = file.path(figures_dir, paste0(COUNTRY_CODE, "_coherence_TEST_CONF.png")), plot = p2, width = 21, height = 21, units = "cm", dpi = 300)
# Export p3 as PNG
ggsave(filename = file.path(figures_dir, paste0(COUNTRY_CODE, "_coherence_CONF_MALTREAT.png")), plot = p3, width = 21, height = 21, units = "cm", dpi = 300)

# Tell user that figures have been exported and where to find them
print(paste0("Coherence plots have been exported as PNG files in the following directory: ", figures_dir))

# %%
# Step 1: Aggregate monthly values
rds_clean_month <- routine_data %>% # GP:was "routine_data_clean"
  mutate(
    YEAR = substr(PERIOD, 1, 4),
    MONTH = substr(PERIOD, 5, 6),
    DATE = as.Date(paste(YEAR, MONTH, "01", sep = "-"))
  ) %>%
  group_by(YEAR, MONTH, DATE) %>%
  summarise(
    SUSP = sum(SUSP, na.rm = TRUE),
    TEST = sum(TEST, na.rm = TRUE),
    CONF = sum(CONF, na.rm = TRUE),
    PRES = sum(PRES, na.rm = TRUE),
    .groups = "drop"
  )

# Step 2: Plot monthly national trends
options(repr.plot.width = 14, repr.plot.height = 6)
rds_clean_month %>%
  pivot_longer(cols = c(SUSP, TEST, CONF, PRES), names_to = "Indicator") %>%
  ggplot(aes(x = DATE, y = value, color = Indicator)) +
  geom_line(linewidth = 1.2) +
  labs(
    title = "Tendances mensuelles nationales des indicateurs composites (après suppression des outliers)",
    x = "Mois", y = "Nombre de cas", color = "Indicateur"
  ) +
  theme_minimal(base_size = 16) +
  theme(
    plot.title = element_text(face = "bold", size = 20),
    axis.title = element_text(size = 16),
    axis.text = element_text(size = 16),
    legend.title = element_text(size = 16),
    legend.text = element_text(size = 16)
  )

# %% [markdown]
# # 3. Carte des populations par district sanitaire (DS)

# %% [markdown]
# ## 3.1. Carte de la Population pour ADM2

# %%
# Code from previous version of the notebook
# Uses continuos scale for population

# Run if population_data is available
# GP: use lighter shapes data for plotting (shapes_data_stsimplified) instead of shapes_data
if (!is.null(population_data) & !is.null(shapes_data_stsimplified)) {  # shapes_data
    # Join population to spatial shapes
    map_data <- shapes_data_stsimplified %>%
      left_join(population_data, by = "ADM2_ID")
    
    # Plot population per district (DS)
    plot <- ggplot(map_data) +
      geom_sf(aes(fill = POPULATION), color = "white", size = 0.2) +
      scale_fill_viridis_c(option = "C", name = "Population") +
      labs(
        title = "Population totale par district sanitaire (DS)",
        subtitle = "Données DHIS2",
        caption = "Source: NMDR / DHIS2"
      ) +
      theme_minimal(base_size = 14) 

    print(plot)

} else {
    print("Population or shapes data not available.")
}

# %% [markdown]
# ## ⚠️ 3.2. Carte de la Population Désagrégée (spécifique au pays)
# Le code suivant est spécifique à chaque pays et repose sur une population désagrégée.

# %%
population_data_filtered <- population_data
if (COUNTRY_CODE == "NER") {
    print("🇳🇪 Executing NER specific code ... ")

    IRdisplay::display_markdown("
        ### 🇳🇪 NER specific code 
        Made ad hoc to allow comparison with data from other or previous analyses. Namely:
        * only year 2022 to 2024
        * specific palette (yellowish to brick red)
        * specific intervals
        * looks at **disaggregated** population <- this is sometimes contry-specific!
")

    # --- Filter data to keep only 2022-2024 ... ---
    years_to_keep <- 2022:2024
    population_data_filtered <- population_data |> filter(YEAR %in% years_to_keep)

    # --- Read data from SNT_metadata.json ---
    metadata_json <- tryCatch({ jsonlite::fromJSON(file.path(CONFIG_PATH, "SNT_metadata.json"))},
     error = function(e) {
           msg <- paste0("Error while loading metadata", conditionMessage(e))  
            cat(msg)   
          stop(msg) 
    })

    # --- Assign population breaks from metadata ---
    value_breaks_tot <- jsonlite::fromJSON(metadata_json$POPULATION_TOTAL$SCALE)
    value_breaks_u5 <- jsonlite::fromJSON(metadata_json$POPULATION_U5$SCALE)
    value_breaks_fe <- jsonlite::fromJSON(metadata_json$POPULATION_PREGNANT$SCALE)

    # --- Create dynamic labels based on breaks ---
    labels_tot <- create_dynamic_labels(value_breaks_tot)
    labels_u5 <- create_dynamic_labels(value_breaks_u5)
    labels_fe <- create_dynamic_labels(value_breaks_fe)

}

# %%
NER_palette_population <- c(
  "1" = "#fae6db",
  "2" = "#f1b195",
  "3" = "#ea7354",
  "4" = "#cc3f32",
  "5" = "#972620"
)

# %% [markdown]
# ### Population Totales

# %%
if (COUNTRY_CODE == "NER") {

  # IMPORTNAT: palette vector MUST be RENAMED with the (dynamic) descriptive labels
names(NER_palette_population) <- labels_tot

plot <- population_data_filtered %>%
  mutate(
    CATEGORY_POPULATION = cut(
      POPULATION,
      breaks = c(0, value_breaks_tot, Inf),
      labels = labels_tot, 
      right = TRUE,
      include.lowest = TRUE
    )
  ) %>% 
  left_join(shapes_data, 
            by = join_by(ADM1_NAME, ADM1_ID, ADM2_NAME, ADM2_ID)) %>% 
  ggplot() +
  geom_sf(aes(geometry = geometry,
              fill = CATEGORY_POPULATION),
          color = "black",
          linewidth = 0.25, 
          show.legend = TRUE
  ) +
  labs(
    title = "Population totale par district sanitaire (DS)",
    subtitle = "Source: NMDR / DHIS2"
  ) +
  scale_fill_manual(
    values = NER_palette_population,   
    limits = labels_tot, 
    drop = FALSE 
  ) +
  facet_wrap(~YEAR, ncol = 3) +
  theme_void() +
  theme(
    plot.title = element_text(face = "bold"),
    plot.subtitle = element_text(margin = margin(5, 0, 20, 0)),
    legend.position = "bottom",
    legend.title = element_blank(),
    strip.text = element_text(face = "bold"),
    legend.key.height = unit(0.5, "line"),
    legend.margin = margin(10, 0, 0, 0)
  )

print(plot)

# Export to see better in high resolution
ggsave(
  filename = file.path(REPORTING_NB_PATH, "outputs", "figures", paste0(COUNTRY_CODE, "_choropleth_population_totals.png")),
  width = 14,
  height = 8,
  dpi = 300
)
}

# %% [markdown]
# ### Population Femmes Enceintes (FE)

# %%
if (COUNTRY_CODE == "NER") {

names(NER_palette_population) <- labels_fe

plot <- population_data_filtered %>%
  mutate(
    CATEGORY_POPULATION = cut(
      POPULATION_FE,
      breaks = c(0, value_breaks_fe, Inf),
      labels = labels_fe, 
      right = TRUE,
      include.lowest = TRUE
    )
  ) %>% 
  left_join(shapes_data, 
            by = join_by(ADM1_NAME, ADM1_ID, ADM2_NAME, ADM2_ID)) %>% 
  ggplot() +
  geom_sf(aes(geometry = geometry,
              fill = CATEGORY_POPULATION),
          color = "black",
          linewidth = 0.25, 
          show.legend = TRUE
  ) +
  labs(
    title = "Population des femmes enceintes par district sanitaire (DS)",
    subtitle = "Source: NMDR / DHIS2"
  ) +
  scale_fill_manual(
    values = NER_palette_population,   
    limits = labels_fe, 
    drop = FALSE # Prevents dropping empty levels from legend
  ) +
  facet_wrap(~YEAR, ncol = 3) +
  theme_void() +
  theme(
    plot.title = element_text(face = "bold"),
    plot.subtitle = element_text(margin = margin(5, 0, 20, 0)),
    legend.position = "bottom",
    legend.title = element_blank(),
    strip.text = element_text(face = "bold"),
    legend.key.height = unit(0.5, "line"),
    legend.margin = margin(10, 0, 0, 0)
  )

print(plot)

# Export to see better in high resolution
ggsave(
  filename = file.path(REPORTING_NB_PATH, "outputs", "figures", paste0(COUNTRY_CODE, "_choropleth_population_fe.png")),
  width = 14,   
  height = 8,
  dpi = 300
)

}

# %% [markdown]
# ### Population Enfants moins de 5 ans (U5)

# %%
if (COUNTRY_CODE == "NER") {

names(NER_palette_population) <- labels_u5

plot <- population_data_filtered %>%
  mutate(
    CATEGORY_POPULATION = cut(
      POPULATION_U5,
      breaks = c(0, value_breaks_u5, Inf),
      labels = labels_u5, 
      right = TRUE,
      include.lowest = TRUE
    )
  ) %>% 
  left_join(shapes_data, 
            by = join_by(ADM1_NAME, ADM1_ID, ADM2_NAME, ADM2_ID)) %>% 
  ggplot() +
  geom_sf(aes(geometry = geometry,
              fill = CATEGORY_POPULATION),
          color = "black",
          linewidth = 0.25, 
          show.legend = TRUE
  ) +
  labs(
    title = "Population des enfants de moins de 5 ans par district sanitaire (DS)",
    subtitle = "Source: NMDR / DHIS2"
  ) +
  scale_fill_manual(
    values = NER_palette_population,   
    limits = labels_u5, 
    drop = FALSE 
  ) +
  facet_wrap(~YEAR, ncol = 3) +
  theme_void() +
  theme(
    plot.title = element_text(face = "bold"),
    plot.subtitle = element_text(margin = margin(5, 0, 20, 0)),
    legend.position = "bottom",
    legend.title = element_blank(),
    strip.text = element_text(face = "bold"),
    legend.key.height = unit(0.5, "line"),
    legend.margin = margin(10, 0, 0, 0)
  )

print(plot)

# Export PNG
ggsave(
  filename = file.path(REPORTING_NB_PATH, "outputs", "figures", paste0(COUNTRY_CODE, "_choropleth_population_u5.png")),
  width = 14,   
  height = 8,
  dpi = 300
)

}

# %% [markdown]
# ## 3.2. <b>Complétude et qualité</b> des données de la Population

# %% [markdown]
# #### Population Totale

# %%
# hist(population_data$POPULATION)
hist(population_data_filtered$POPULATION)

# %%
ggplot(population_data_filtered) +
  geom_point(aes(x = POPULATION,
                 y = fct_reorder(ADM2_NAME, POPULATION),
                 color = factor(YEAR))
             ) +
  facet_grid(rows = "ADM1_NAME", 
             scale = "free_y", 
             space = "free_y", 
             switch = "y") +
  scale_x_continuous(breaks = c(0, 2e+05, 4e+05, 6e+05, 8e+05, 1e+06, 1.5e+06),
                     labels = scales::comma) +
  scale_color_viridis_d(option = "mako", end = 0.8) +
  labs(color = "Année") +
  theme_minimal() +
  theme(
    axis.text = element_text(size = 5),
    axis.title.x = element_text(size = 5),
    axis.title.y = element_blank(),
    strip.text.y = element_text(size = 7),
    strip.placement = "outside",
    panel.grid.minor.x = element_blank(),
    legend.position = "bottom"
  )

# # Export PNG
# # height should be proportional to the number of districts (ADM2_NAME) we have, to avoid having a super compressed plot if we have many districts (e.g., >20) 
# # or a super stretched plot if we have few districts (e.g., <10)
# height_cm <- max(15, min(60, length(unique(population_data_filtered$ADM2_NAME)) * 0.5)) # 0.5 cm per district, with a minimum of 15 cm and a maximum of 60 cm
# ggsave(
#   filename = file.path(REPORTING_NB_PATH, "outputs", "figures", "scatter_population_totale_by_year.png"),
#   units = "cm",
#   width = 15,
#   height = height_cm,
#   bg = "white"
# )

# %%
# Export PNG
# height should be proportional to the number of districts (ADM2_NAME) we have, to avoid having a super compressed plot if we have many districts (e.g., >20) 
# or a super stretched plot if we have few districts (e.g., <10)
height_cm <- max(15, min(90, length(unique(population_data_filtered$ADM2_NAME)) * 0.5)) # 0.5 cm per district, with a minimum of 15 cm and a maximum of 60 cm
ggsave(
  filename = file.path(REPORTING_NB_PATH, "outputs", "figures", "scatter_population_totale_by_year.png"),
  units = "cm",
  width = 15,
  height = height_cm,
  bg = "white",
  dpi = 150
)

# %% [markdown]
# #### Population Femmes Enceintes (FE)

# %%
# Wrap in if statement to avoid errors if POPULATION_FE is missing
if ("POPULATION_FE" %in% names(population_data_filtered)) { 
    hist(population_data_filtered$POPULATION_FE)
}

# %%
if ("POPULATION_FE" %in% names(population_data_filtered)) { 
  
ggplot(population_data_filtered) +
  geom_point(aes(x = POPULATION_FE,
                 y = fct_reorder(ADM2_NAME, POPULATION_FE),
                 color = factor(YEAR))
             ) +
  facet_grid(rows = "ADM1_NAME", 
             scale = "free_y", 
             space = "free_y", 
             switch = "y") +
  scale_x_continuous(breaks = c(0, 2e+04, 4e+04, 6e+04, 8e+05, 1e+06, 1.5e+06),
                     labels = scales::comma) +
  scale_color_viridis_d(option = "mako", end = 0.8) +
  labs(
      # title = ""
      color = "Année") +
  theme_minimal() +
  theme(
    axis.text = element_text(size = 7),
    axis.title.x = element_text(size = 7),
    axis.title.y = element_blank(),
    strip.placement = "outside",
    panel.grid.minor.x = element_blank(),
    legend.position = "bottom"
  )

}

# %% [markdown]
# #### Population Enfants moins de 5 ans (U5)

# %%
if ("POPULATION_U5" %in% names(population_data_filtered)) {
    hist(population_data_filtered$POPULATION_U5)
}

# %%
if ("POPULATION_U5" %in% names(population_data_filtered)) {

ggplot(population_data_filtered) +
  geom_point(aes(x = POPULATION_U5,
                 y = fct_reorder(ADM2_NAME, POPULATION_U5, .na_rm = FALSE),
                 color = factor(YEAR))
             ) +
  facet_grid(rows = "ADM1_NAME", 
             scale = "free_y", 
             space = "free_y", 
             switch = "y") +
  scale_x_continuous(breaks = c(0, 2e+04, 4e+04, 6e+04, 8e+04, 1e+05, 1.5e+05),
                     labels = scales::comma) +
  scale_color_viridis_d(option = "mako", end = 0.8) +
  labs(
      # title = ""
      color = "Année") +
  theme_minimal() +
  theme(
    axis.text = element_text(size = 7),
    axis.title.x = element_text(size = 7),
    axis.title.y = element_blank(),
    strip.placement = "outside",
    panel.grid.minor.x = element_blank(),
    legend.position = "bottom"
  )

}
