# %% [markdown]
# ## Setup start

# %%
SNT_ROOT_PATH <- "~/workspace"

# %%
source(file.path(SNT_ROOT_PATH, "pipelines/snt_dhis2_formatting/utils/snt_dhis2_formatting.r"))
setup_var <- get_setup_variables(SNT_ROOT_PATH = SNT_ROOT_PATH, packages=c("arrow", "dplyr", "tidyr", "stringr", "stringi", "jsonlite", "httr", "reticulate","glue"))

# Load config
config_json <- load_snt_config(file.path(setup_var$CONFIG_PATH, "SNT_config.json"))

# Save config variables
COUNTRY_CODE <- config_json$SNT_CONFIG$COUNTRY_CODE
ADMIN_1 <- toupper(config_json$SNT_CONFIG$DHIS2_ADMINISTRATION_1)
ADMIN_2 <- toupper(config_json$SNT_CONFIG$DHIS2_ADMINISTRATION_2)
extracts_dataset_id <- config_json$SNT_DATASET_IDENTIFIERS$DHIS2_DATASET_EXTRACTS
ou_level <- config_json$SNT_CONFIG$ANALYTICS_ORG_UNITS_LEVEL

# %% [markdown]
# ### Load DHIS2 reporting rates data
#
# -Load DHIS2 reporting rates data from latest dataset version (extracts)

# %%
# Load file from dataset
dhis2_data <- load_dataset_file(extracts_dataset_id, paste0(COUNTRY_CODE, "_dhis2_raw_reporting.parquet"), verbose=FALSE)
log_msg(glue("DHIS2 reporting rate data loaded from dataset : '{extracts_dataset_id}' dataframe dimensions: {paste(dim(dhis2_data), collapse=', ')}"))
head(dhis2_data, 3)

# %% [markdown]
# ## Reporting rates dataset formatting

# %% [markdown]
# ### Format (clean) pyramid and dataset names

# %%
log_msg(glue("Start DHIS2 reporting rates formatting."))   

# Standard string formats 
dhis2_data_clean <- clean_input_data(dhis2_data, verbose=FALSE)
head(dhis2_data_clean, 3)

# %% [markdown]
# ### Column selection

# %%
# Set administrative columns
adm_1_id_col <- gsub("_NAME", "_ID", ADMIN_1)
adm_1_name_col <- ADMIN_1
adm_2_id_col <- gsub("_NAME", "_ID", ADMIN_2)
adm_2_name_col <- ADMIN_2

# Remove duplicate source columns (country extracts may contain duplicate names)
dup_cols <- names(dhis2_data_clean)[duplicated(names(dhis2_data_clean))]
if (length(dup_cols) > 0) {
    log_msg(glue("[WARNING] Duplicate column names detected in reporting data: {paste(unique(dup_cols), collapse=', ')}. Keeping first occurrence only."), level = "warning")
    dhis2_data_clean <- dhis2_data_clean[, !duplicated(names(dhis2_data_clean)), drop = FALSE]
}

# Determine OU columns dynamically with fallback if configured level is missing
available_cols <- names(dhis2_data_clean)
preferred_ou_id_col   <- glue("LEVEL_{ou_level}_ID")
preferred_ou_name_col <- glue("LEVEL_{ou_level}_NAME")

if (preferred_ou_id_col %in% available_cols && preferred_ou_name_col %in% available_cols) {
    adm_ou_id_col   <- preferred_ou_id_col
    adm_ou_name_col <- preferred_ou_name_col
} else {
    # Find all LEVEL_x_ID columns present in the data and pick the highest level available
    level_id_cols <- available_cols[grepl("^LEVEL_\\d+_ID$", available_cols)]
    levels_present <- as.integer(gsub("LEVEL_(\\d+)_ID", "\\1", level_id_cols))
    valid_levels <- levels_present[
        glue("LEVEL_{levels_present}_NAME") %in% available_cols
    ]
    if (length(valid_levels) == 0) stop(glue("[ERROR] No LEVEL_x_ID/NAME columns found in reporting rates data."))
    fallback_level  <- max(valid_levels)
    adm_ou_id_col   <- glue("LEVEL_{fallback_level}_ID")
    adm_ou_name_col <- glue("LEVEL_{fallback_level}_NAME")
    log_msg(glue("[WARNING] Configured OU level {ou_level} not available. Using fallback level {fallback_level} ({adm_ou_id_col}, {adm_ou_name_col})."), level = "warning")
}

# Administrative columns list
admin_columns <- unique(c(
    adm_1_id_col,
    adm_1_name_col,
    adm_2_id_col,
    adm_2_name_col,
    adm_ou_id_col,
    adm_ou_name_col
))

# Validate all required admin columns exist
missing_admin <- setdiff(admin_columns, available_cols)
if (length(missing_admin) > 0) {
    stop(glue("[ERROR] Missing required admin columns in reporting rates data: {paste(missing_admin, collapse=', ')}"))
}

# Select relevant columns for SNT
fixed_cols <- c("PE", "VALUE", "PRODUCT_UID", "PRODUCT_NAME", "PRODUCT_METRIC")
selected_cols <- unique(c(fixed_cols, admin_columns))
dhis2_data_selection <- dhis2_data_clean[selected_cols]

print(dim(dhis2_data_selection))
head(dhis2_data_selection, 3)

# %% [markdown]
# ### Apply SNT format

# %%
# Select and rename columns
dhis2_data_formatted <- dhis2_data_selection %>%
    mutate(
        PE = as.numeric(PE),
        YEAR = as.numeric(substr(PE, 1, 4)),
        MONTH = as.numeric(substr(PE, 5, 6)),
        VALUE = as.numeric(VALUE)
    ) %>%
    select(
        PERIOD = PE,
        YEAR,
        MONTH,
        ADM1_NAME = !!sym(adm_1_name_col),
        ADM1_ID = !!sym(adm_1_id_col),           
        ADM2_NAME = !!sym(adm_2_name_col),
        ADM2_ID = !!sym(adm_2_id_col),  
        OU_ID = !!sym(adm_ou_id_col),
        OU_NAME = !!sym(adm_ou_name_col),                 
        all_of(fixed_cols)
     )

# Sort dataframe by period
dhis2_data_formatted <- dhis2_data_formatted[order(as.numeric(dhis2_data_formatted$PERIOD)), ]

print(dim(dhis2_data_formatted))
head(dhis2_data_formatted, 3)

# %% [markdown]
# ## Output formatted population data

# %%
FORMATTED_DATA_PATH <- file.path(setup_var$DATA_PATH, "dhis2", "extracts_formatted")

# write files
write_parquet(dhis2_data_formatted, file.path(FORMATTED_DATA_PATH, paste0(COUNTRY_CODE, "_reporting.parquet")))
write.csv(dhis2_data_formatted, file.path(FORMATTED_DATA_PATH, paste0(COUNTRY_CODE, "_reporting.csv")), row.names = FALSE)

# log
log_msg(glue("Formatted reporting data saved under: {file.path(FORMATTED_DATA_PATH, paste0(COUNTRY_CODE, '_reporting.parquet'))}"))

# %% [markdown]
# ### Data Summary

# %%
# Data summary
print(summary(dhis2_data_formatted))
